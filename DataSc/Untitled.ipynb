# %%
import pandas as pd

# %%
df = pd.read_csv('sales.csv')

# %%
df.head()
# Out:
#    Year  Product       line Product.1  type  Product.2  Order method  \
# 0  2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag
# 1  2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag
# 2  2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag
# 3  2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag
# 4  2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag
#
#       type.1   Retailer country    Revenue
# 0  Telephone     United  States  315044.33
# 1  Telephone     Canada     NaN   14313.48
# 2  Telephone     Mexico     NaN  156644.47
# 3  Telephone  venezuela     NaN   59191.72
# 4  Telephone      Japan     NaN    7029.33

# %%
df.Revenue.value_counts().plot(kind = "pie")
# Out:
# <Axes: ylabel='count'>

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 9257-A4C2
#
#  Directory of C:\Users\OLADOSU\Desktop\DataSc
#
# 10/31/2023  07:09 AM    <DIR>          .
# 10/31/2023  07:09 AM    <DIR>          ..
# 10/31/2023  11:55 AM    <DIR>          .ipynb_checkpoints
# 10/26/2023  01:34 PM             3,291 class1.ipynb
# 10/31/2023  06:05 AM                51 exported-car-sales.csv
# 10/26/2023  03:24 AM             8,297 sales.csv
# 10/31/2023  07:09 AM           160,714 Untitled.ipynb
#                4 File(s)        172,353 bytes
#                3 Dir(s)  232,475,226,112 bytes free

# %% [markdown]
# ## 2 main datatypes

# %% [markdown]
# ## Series

# %%
series = pd.Series(['BMW', 'TOYOTA', 'Honda'])
series
# Out:
# 0       BMW
# 1    TOYOTA
# 2     Honda
# dtype: object

# %%
car_color = pd.Series(['red', 'blue', 'yellow'])
car_color
# Out:
# 0       red
# 1      blue
# 2    yellow
# dtype: object

# %% [markdown]
# ## Data frame

# %%
car_data = pd.DataFrame({"cartype":series, "color":car_color})
car_data
# Out:
#   cartype   color
# 0     BMW     red
# 1  TOYOTA    blue
# 2   Honda  yellow

# %%
## exporting or converting file type. we use the function "to_"
car_data.to_csv("exported-car-sales.csv")

# %%
df.head(6)
# Out:
#    Year  Product       line Product.1  type  Product.2  Order method  \
# 0  2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag
# 1  2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag
# 2  2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag
# 3  2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag
# 4  2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag
# 5  2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag
#
#       type.1   Retailer country    Revenue
# 0  Telephone     United  States  315044.33
# 1  Telephone     Canada     NaN   14313.48
# 2  Telephone     Mexico     NaN  156644.47
# 3  Telephone  venezuela     NaN   59191.72
# 4  Telephone      Japan     NaN    7029.33
# 5  Telephone      Korea     NaN   52613.47

# %%
df.tail(10)
# Out:
#     Year  Product       line Product.1  type  Product.2  Order method type.1  \
# 90  2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag   Mail
# 91  2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag   Mail
# 92  2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag   Mail
# 93  2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag   Mail
# 94  2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag   Mail
# 95  2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag   Mail
# 96  2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag   Mail
# 97  2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag   Mail
# 98  2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag   Mail
# 99  2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag   Mail
#
#        Retailer  country    Revenue
# 90        China      NaN   23042.67
# 91    Singapore      NaN   59479.91
# ...

# %% [markdown]
# ## Exporting a Dataframe

# %%
car_data.to_csv("exported-car-sales.csv", index=False)

# %%
exported_car_sales = pd.read_csv("exported-car-sales.csv")
exported_car_sales
# Out:
#   cartype   color
# 0     BMW     red
# 1  TOYOTA    blue
# 2   Honda  yellow

# %%
sales_item = pd.read_csv("sales.csv")
sales_item
# Out:
#     Year  Product       line Product.1  type  Product.2  Order method  \
# 0   2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag
# 1   2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag
# 2   2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag
# 3   2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag
# 4   2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag
# ..   ...      ...        ...       ...   ...        ...    ...    ...
# 95  2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag
# 96  2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag
# 97  2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag
# 98  2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag
# 99  2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag
#
#        type.1   Retailer  country    Revenue
# 0   Telephone     United   States  315044.33
# ...

# %% [markdown]
# ## Attributes

# %%
datatype=sales_item.dtypes
columns=sales_item.columns
indexe=sales_item.index
info=sales_item.info

# %%
##methods
describe=sales_item.describe()
describe
# Out:
#          Year        Revenue
# count   100.0     100.000000
# mean   2004.0   75543.366300
# std       0.0   70060.167447
# min    2004.0    6615.840000
# 25%    2004.0   32575.022500
# 50%    2004.0   59479.910000
# 75%    2004.0   78551.192500
# max    2004.0  348446.250000

# %%
sales_item["Revenue"].mean()
# Out:
# 75543.3663

# %%
sales_item["Revenue"].sum()
# Out:
# 7554336.629999999

# %% [markdown]
# ## Loc (location) & iloc(index location)

# %%
animals = pd.Series(["cat", "dog", "bird","panda","snake"], index=[0,3,9,8,3])
animals

# %%
animals.loc[3]
# Out:
# 3      dog
# 3    snake
# dtype: object

# %%
animals.iloc[3]
# Out:
# 'panda'

# %% [markdown]
# ## slicing

# %%
animals.iloc[:3]
# Out:
# 0     cat
# 3     dog
# 9    bird
# dtype: object

# %%
animals.iloc[3:4]
# Out:
# 8    panda
# dtype: object

# %%
sales_item
# Out:
#     Year  Product       line Product.1  type  Product.2  Order method  \
# 0   2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag
# 1   2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag
# 2   2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag
# 3   2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag
# 4   2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag
# ..   ...      ...        ...       ...   ...        ...    ...    ...
# 95  2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag
# 96  2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag
# 97  2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag
# 98  2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag
# 99  2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag
#
#        type.1   Retailer  country    Revenue
# 0   Telephone     United   States  315044.33
# ...

# %%
sales_item["Retailer"].loc[3]
# Out:
# 'venezuela'

# %%
sales_item[sales_item["Retailer"] =="United"]
# Out:
#     Year  Product       line Product.1  type  Product.2  Order method  \
# 0   2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag
# 15  2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag
# 21  2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag
# 36  2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag
# 42  2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag
# 57  2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag
# 63  2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag
# 78  2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag
# 84  2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag
# 99  2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag
#
#        type.1 Retailer  country    Revenue
# 0   Telephone   United   States  315044.33
# 15  Telephone   United  Kingdom   62800.36
# 21      visit   United   States    7367.64
# ...

# %% [markdown]
# ## Comparing columns

# %%
pd.crosstab(sales_item["Retailer"] , sales_item["country"])
# Out:
# country   Kingdom  States
# Retailer
# United          5       4

# %% [markdown]
# ## chart with compared columns

# %%
pd.crosstab(sales_item["Year"] , sales_item["Revenue"]).plot(kind="bar")
# Out:
# <Axes: xlabel='Year'>

# %% [markdown]
# ## charts

# %%
sales_item["Year"].hist()
# Out:
# <Axes: >
